# %% [markdown]
# <a href="https://colab.research.google.com/github/Lokeshpolice/Lokeshpolice/blob/main/Lab_02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 3.1 Loading the Data

# %%
# Import our libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.datasets import load_iris # A function to load our case file

# Load the dataset
iris_data = load_iris()

# Create a DataFrame (our table)
iris_df = pd.DataFrame(data=iris_data.data, columns=iris_data.feature_names)

# Add the 'species' column to our table
iris_df['species'] = iris_data.target_names[iris_data.target]

# %% [markdown]
# 3.2

# %%
print(iris_df.head())
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#   species
# 0  setosa
# 1  setosa
# 2  setosa
# 3  setosa
# 4  setosa

# %% [markdown]
# 3.3

# %%
# Get a summary of the DataFrame
iris_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   sepal length (cm)  150 non-null    float64
#  1   sepal width (cm)   150 non-null    float64
#  2   petal length (cm)  150 non-null    float64
#  3   petal width (cm)   150 non-null    float64
#  4   species            150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %% [markdown]
# 3.4

# %%
# Get descriptive statistics
print(iris_df.describe())
# Out:
#        sepal length (cm)  sepal width (cm)  petal length (cm)  \
# count         150.000000        150.000000         150.000000
# mean            5.843333          3.057333           3.758000
# std             0.828066          0.435866           1.765298
# min             4.300000          2.000000           1.000000
# 25%             5.100000          2.800000           1.600000
# 50%             5.800000          3.000000           4.350000
# 75%             6.400000          3.300000           5.100000
# max             7.900000          4.400000           6.900000
#
#        petal width (cm)
# count        150.000000
# mean           1.199333
# std            0.762238
# min            0.100000
# 25%            0.300000
# 50%            1.300000
# 75%            1.800000
# max            2.500000

# %% [markdown]
# Part 4: Cleaning The Scene (Data Preprocessing)

# %%
# Check for null (missing) values in each column
print(iris_df.isnull().sum())
# Out:
# sepal length (cm)    0
# sepal width (cm)     0
# petal length (cm)    0
# petal width (cm)     0
# species              0
# dtype: int64

# %%
# Count the number of duplicated rows
duplicates = iris_df.duplicated().sum()
print(f"Number of duplicate rows: {duplicates}")
# Out:
# Number of duplicate rows: 1

# %%
# Remove duplicates, keeping the first instance
iris_df = iris_df.drop_duplicates()
print("Duplicates removed. Let's check info again:")
iris_df.info()
# Out:
# Duplicates removed. Let's check info again:
# <class 'pandas.core.frame.DataFrame'>
# Index: 149 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   sepal length (cm)  149 non-null    float64
#  1   sepal width (cm)   149 non-null    float64
#  2   petal length (cm)  149 non-null    float64
#  3   petal width (cm)   149 non-null    float64
#  4   species            149 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 7.0+ KB

# %% [markdown]
# Part 5: Drawing The Connections (Visualization)

# %%
# Set the style of our plots to be pretty
sns.set_style('whitegrid')

# Create a histogram of sepal width
plt.figure(figsize=(8, 6)) # Create a canvas for our plot
sns.histplot(data=iris_df, x='sepal width (cm)', kde=True, color='purple')
plt.title('Distribution of Sepal Width', fontsize=16)
plt.show()

# %% [markdown]
# 5.2 Comparing Two Clues (Bivariate Plots)

# %%
# Create a scatter plot of petal length vs petal width
# The 'hue' parameter colors the points based on the 'species' column
plt.figure(figsize=(10, 7))
sns.scatterplot(data=iris_df, x='petal length (cm)', y='petal width (cm)', hue='species', s=100, palette='viridis')
plt.title('Petal Length vs. Petal Width by Species', fontsize=16)
plt.show()

# %%
# Create a pair plot of the entire dataset, colored by species
sns.pairplot(data=iris_df, hue='species')
plt.show()

# %% [markdown]
# MY Turn

# %%
print(iris_df.tail())
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#        species
# 145  virginica
# 146  virginica
# 147  virginica
# 148  virginica
# 149  virginica

# %% [markdown]
# 3.3

# %%
iris_df.shape
# Out:
# (150, 5)

# %%
iris_df['petal length (cm)'].describe()
# Out:
# count    150.000000
# mean       3.758000
# std        1.765298
# min        1.000000
# 25%        1.600000
# 50%        4.350000
# 75%        5.100000
# max        6.900000
# Name: petal length (cm), dtype: float64

# %%
duplicates = iris_df.duplicated().sum()
print(f"Number of duplicate rows: {duplicates}")
# Out:
# Number of duplicate rows: 0

# %%
# Set the style of our plots to be pretty
sns.set_style('whitegrid')

# Create a histogram of sepal width
plt.figure(figsize=(10, 8)) # Create a canvas for our plot
sns.histplot(data=iris_df, x='sepal width (cm)', kde=True, color='green')
plt.title('Distribution of Sepal Width', fontsize=20)
plt.show()

# %%
plt.figure(figsize=(10, 7))
sns.scatterplot(data=iris_df, x='sepal length (cm)', y='sepal width (cm)', hue='species', s=100, palette='viridis')
plt.title('sepal length  vs. sepal width', fontsize=16)
plt.show()

# %% [markdown]
# Part 6: Your Turn to be the Detective

# %%
# Task 1
iris_df['species'].value_counts()
# Out:
# species
# setosa        50
# versicolor    50
# virginica     49
# Name: count, dtype: int64

# %%
# Task 1.2
iris_df.groupby('species')['petal length (cm)'].mean()
# Out:
# species
# setosa        1.462000
# versicolor    4.260000
# virginica     5.561224
# Name: petal length (cm), dtype: float64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Task 2
plt.figure(figsize=(8,5))
sns.histplot(iris_df['petal length (cm)'], bins=20, kde=True)
plt.title("Histogram of Petal Length")
plt.xlabel("Petal Length (cm)")
plt.ylabel("Count")
plt.show()

# %%
# Task 2
plt.figure(figsize=(8,5))
sns.boxplot(data=iris_df, x='species', y='sepal width (cm)')
plt.title("Box Plot of Sepal Width by Species")
plt.show()

# %%
#task 3
plt.figure(figsize=(8,5))
sns.boxplot(data=iris_df, x='species', y='petal length (cm)')
plt.title("violin plot of Petal Width by Species")
plt.show()

# %% [markdown]
# 1)The violin plot shows the distribution shape of petal widths for each species:
#
# Setosa has very small petal widths, tightly grouped.
#
# Versicolor has medium widths, spread out more evenly.
#
# Virginica has the widest petals, with a larger range and higher density at higher values.
